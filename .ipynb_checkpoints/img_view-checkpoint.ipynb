# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from ipywidgets import interact, fixed
from IPython.display import clear_output
import random
import SimpleITK as sitk

# %%
def display_image(image_z, npa):
    plt.imshow(npa[image_z,:,:],cmap=plt.cm.Greys_r);
    plt.axis('off')
    plt.show()

# %%
DATA = "/work/data"
# Temp
SKULL_STRIP = f'{DATA}/temp/skull_strip'
IMG_REG = f'{DATA}/temp/img_reg'
DENOISE = f'{DATA}/temp/denoise'
PETPVC = f'{DATA}/temp/petpvc'
BAIS_COR = f'{DATA}/temp/bias_cor'
TEMP_OUTPUT = f'{DATA}/temp/output'

# %%
# preprocessing stages
# Out:
# ['002_S_2073_2', '002_S_2073_3']

# %%
dir='002_S_2073_3'
filtered=True
intent=''
indent = intent if filtered else "_preprocessed"
mri_file = f"/content/drive/MyDrive/sample{indent}/{dir}/mri.nii"
pet_file = f"/content/drive/MyDrive/sample{indent}/{dir}/pet.nii"
print(mri_file,pet_file)
# Out:
# /content/drive/MyDrive/sample/002_S_2073_3/mri.nii /content/drive/MyDrive/sample/002_S_2073_3/pet.nii

# %%
# !cp -r /content/drive/MyDrive/sample_preprocessed/002_S_2073_2 .

# %%
image =  sitk.ReadImage(pet_file, sitk.sitkFloat32)
interact(display_image, image_z=(0,image.GetSize()[2]-1), npa = fixed(sitk.GetArrayViewFromImage(image)));
# Out:
# interactive(children=(IntSlider(value=51, description='image_z', max=103), Output()), _dom_classes=('widget-in…

# %%
# !ws-normalize -i /content/002_S_2073_2 -o /content/fcm-output
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
image =  sitk.ReadImage(mri_file, sitk.sitkFloat32)
interact(display_image, image_z=(0,image.GetSize()[2]-1), npa = fixed(sitk.GetArrayViewFromImage(image)));
# Out:
# interactive(children=(IntSlider(value=51, description='image_z', max=103), Output()), _dom_classes=('widget-in…

# %%
image =  sitk.ReadImage("/content/fcm-output/mri_ws.nii", sitk.sitkFloat32)
interact(display_image, image_z=(0,image.GetSize()[2]-1), npa = fixed(sitk.GetArrayViewFromImage(image)));
# Out:
# interactive(children=(IntSlider(value=51, description='image_z', max=103), Output()), _dom_classes=('widget-in…

# %%
# !deepbrain-extractor -i /content/drive/MyDrive/sample/002_S_2073_3/mri.nii -o ./output/
# Out:
# 2021-04-20 06:16:25.680690: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "/usr/local/bin/deepbrain-extractor", line 55, in <module>
#     run(args.input, args.output)
#   File "/usr/local/bin/deepbrain-extractor", line 27, in run
#     extractor = Extractor()
#   File "/usr/local/lib/python3.7/dist-packages/deepbrain/extractor.py", line 14, in __init__
#     self.load_pb()
#   File "/usr/local/lib/python3.7/dist-packages/deepbrain/extractor.py", line 18, in load_pb
#     self.sess = tf.Session(graph=graph)
# AttributeError: module 'tensorflow' has no attribute 'Session'

# %%
# !python run.py
# Out:
# 2021-04-20 06:19:14.979765: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Traceback (most recent call last):
#   File "run.py", line 9, in <module>
#     ext = Extractor()
#   File "/usr/local/lib/python3.7/dist-packages/deepbrain/extractor.py", line 14, in __init__
#     self.load_pb()
#   File "/usr/local/lib/python3.7/dist-packages/deepbrain/extractor.py", line 18, in load_pb
#     self.sess = tf.Session(graph=graph)
# AttributeError: module 'tensorflow' has no attribute 'Session'
